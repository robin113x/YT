# %% [markdown]
# <a href="https://colab.research.google.com/github/robin113x/YT/blob/main/Transfer_files_from_Mega_to_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@markdown <br><center><img src='https://upload.wikimedia.org/wikipedia/commons/thumb/d/da/Google_Drive_logo.png/600px-Google_Drive_logo.png' height="50" alt="Gdrive-logo"/></center>
#@markdown <center><h3>Mount GDrive to /content/drive</h3></center><br>
MODE = "MOUNT" #@param ["MOUNT", "UNMOUNT"]
#Mount your Gdrive!
from google.colab import drive
drive.mount._DEBUG = False
if MODE == "MOUNT":
  drive.mount('/content/drive', force_remount=True)
elif MODE == "UNMOUNT":
  try:
    drive.flush_and_unmount()
  except ValueError:
    pass
  get_ipython().system_raw("rm -rf /root/.config/Google/DriveFS")
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !apt install megatools -y
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# megatools is already the newest version (1.10.3-1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.

# %%
# !megadl "https://mega.nz/folder/0jInmS5B#6wkZrrupastLrbn3vEITJQ" --path "/content/drive/MyDrive/Conversation&Domination"
# Out:
# ERROR: File already exists at /content/drive/MyDrive/Conversation&Domination/Phase 6 - Bonus Tools Series/2 Dynamite Theory (Fuse Length).mp4
# ERROR: File already exists at /content/drive/MyDrive/Conversation&Domination/Phase 6 - Bonus Tools Series/1 Optimal Approach Theory.mp4
# ERROR: File already exists at /content/drive/MyDrive/Conversation&Domination/Phase 6 - Bonus Tools Series/5 The Female Party Starter.mp4
# ERROR: File already exists at /content/drive/MyDrive/Conversation&Domination/Phase 6 - Bonus Tools Series/3 The Power of Muting Emotions.mp4
# ERROR: File already exists at /content/drive/MyDrive/Conversation&Domination/Phase 6 - Bonus Tools Series/4 Wingman Tips.mp4
# ERROR: File already exists at /content/drive/MyDrive/Conversation&Domination/Phase 4 - The 7 Ways to Make Her Chase/1 The Chasing to Choosing Concept (Intro).mp4
# ERROR: File already exists at /content/drive/MyDrive/Conversation&Domination/Phase 4 - The 7 Ways to Make Her Chase/2 Chase Mechanism #1.mp4
# ...
